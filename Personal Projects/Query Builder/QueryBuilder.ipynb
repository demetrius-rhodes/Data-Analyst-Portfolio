# %% [markdown]
# # Query Builder Data Project
# ___
#
# When a report is scheduled on the BI platform, recipient(s) must be entered. The following information is stored when a report is scheduled: report name, description, subject, mail address, cc, and bcc. The information can be queried and is stored in a very messy data format in excel. The purpose of this script is to do a strategic cleaning to extract all the report information and store it into a uniform table.
#
# ### Import Packages

# %%
import pandas as pd
import numpy as np
import os
import re

# change the current working directory 
# to specified path
os.chdir('C:/Users/DDR33/Software/Jupyter/Portfolio/Query Builder')

# FileName
file = 'QueryBuilder.xlsx'

# Read in the excel file
qb = pd.read_excel(file, engine='openpyxl')

# Dataframe the data will be stored in
querybuilder_data = pd.DataFrame(columns=['SI_NAME', 'SI_DESCRIPTION', 'SI_MAIL_SUBJECT', 'SI_MAIL_ADDRESSES', 'SI_MAIL_CC', 'SI_MAIL_BCC', 'SI_MAIL_MESSAGE'])

# Change how many columns are viewed
pd.set_option('display.max_columns', 1000000)
pd.set_option('display.max_rows', 1000000)

qb.head(20)
# Out:
#                                                  Col1                  Col2  \
# 0   SAP BusinessObjects Business Intelligence plat...                   NaN
# 1                                                 NaN                   NaN
# 2               Number of InfoObject(s) returned: 109                   NaN
# 3                                                 NaN                   NaN
# 4                                                 NaN                   NaN
# 5                                                 NaN                   NaN
# 6                                                 NaN                   NaN
# 7                                               1/109                   top
# 8                                          Properties                   NaN
# 9                                      SI_DESCRIPTION  monthly for Teresa C
# 10                                            SI_NAME  non-english x active
# 11                                    Scheduling Info                   NaN
# 12                                    SI_DESTINATIONS              SI_TOTAL
# 13                                                NaN                     1
# 14                                                NaN                   NaN
# 15                                                NaN                   NaN
# 16                                                NaN                   NaN
# 17                                                NaN                   NaN
# 18                                                NaN                   NaN
# 19                                                NaN                   NaN
#
#                        Col3               Col4  \
# 0                       NaN                NaN
# 1                       NaN                NaN
# 2                       NaN                NaN
# 3                       NaN                NaN
# 4                       NaN                NaN
# 5                       NaN                NaN
# 6                       NaN                NaN
# 7                       NaN                NaN
# 8                       NaN                NaN
# 9                       NaN                NaN
# 10                      NaN                NaN
# 11                      NaN                NaN
# 12                        1                NaN
# 13  SI_DEST_SCHEDULEOPTIONS     SI_SENDER_NAME
# 14                      NaN    SI_MAIL_MESSAGE
# 15                      NaN    SI_MAIL_SUBJECT
# 16                      NaN  SI_MAIL_ADDRESSES
# 17                      NaN                NaN
# 18                      NaN         SI_MAIL_CC
# 19                      NaN        SI_MAIL_BCC
#
#                                  Col5                Col6 Col7
# 0                                 NaN                 NaN  NaN
# 1                                 NaN                 NaN  NaN
# 2                                 NaN                 NaN  NaN
# 3                                 NaN                 NaN  NaN
# 4                                 NaN                 NaN  NaN
# 5                                 NaN                 NaN  NaN
# 6                                 NaN                 NaN  NaN
# 7                                 NaN                 NaN  NaN
# 8                                 NaN                 NaN  NaN
# 9                                 NaN                 NaN  NaN
# 10                                NaN                 NaN  NaN
# 11                                NaN                 NaN  NaN
# 12                                NaN                 NaN  NaN
# 13                                NaN                 NaN  NaN
# 14  added 1/4/19 monthly for Teresa C                 NaN  NaN
# 15                          %SI_NAME%                 NaN  NaN
# 16                           SI_TOTAL                   1  NaN
# 17                                  1  Email1@example.org  NaN
# 18                           SI_TOTAL                   0  NaN
# 19                           SI_TOTAL                   0  NaN

# %%
qb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2473 entries, 0 to 2472
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Col1    657 non-null    object
#  1   Col2    543 non-null    object
#  2   Col3    327 non-null    object
#  3   Col4    1090 non-null   object
#  4   Col5    1263 non-null   object
#  5   Col6    936 non-null    object
#  6   Col7    108 non-null    object
# dtypes: object(7)
# memory usage: 135.4+ KB

# %% [markdown]
# ### Data Information
# ___
#
# This is an example of the messy dataframe. The each report will be stored in the **querybuilder_data** dataframe. All the emails have been replaced with **email(number)@example.com** for the purpose of this project.
#
# |Column|Description|
# |------|-----------|
# |SI_NAME|The name of the report|
# |SI_DESCRIPTION|The description of what the report contains|
# |SI_MAIL_SUBJECT|The subject of the email that contains the report as an attachment|
# |SI_MAIL_ADDRESS|The recipient(s) of the email|
# |SI_MAIL_CC|The recipient(s) of the email that are CC'd|
# |SI_MAIL_BCC|The recipient(s) of the email that are BCC'd|
# |SI_MAIL_MESSAGE|The body of the email|
#
# ### Clean Columns

# %% [markdown]
# ### SI_NAME
#
# Looking at the **qb** table in the first column(**col1**) where it is **SI_NAME**, the name of the report should be in **col2** at the same index. Each report name in **col2** will be stored in the **querybuilder_data** dataframe.

# %%
querybuilder_data['SI_NAME'] = qb[qb.iloc[:,0] == 'SI_NAME'].iloc[:,1].reset_index(drop=True)
querybuilder_data.head()
# Out:
#                                           SI_NAME SI_DESCRIPTION  \
# 0                            non-english x active            NaN
# 1                            CLT - Child Caseload            NaN
# 2      CRCF- Client Roster by CRCF with Addresses            NaN
# 3  Crosstab - Advoc & SvcAbbrev x month Dillon v2            NaN
# 4              Tx - 05 Transactions by Advoc 1 v2            NaN
#
#   SI_MAIL_SUBJECT SI_MAIL_ADDRESSES SI_MAIL_CC SI_MAIL_BCC SI_MAIL_MESSAGE
# 0             NaN               NaN        NaN         NaN             NaN
# 1             NaN               NaN        NaN         NaN             NaN
# 2             NaN               NaN        NaN         NaN             NaN
# 3             NaN               NaN        NaN         NaN             NaN
# 4             NaN               NaN        NaN         NaN             NaN

# %%
querybuilder_data['SI_NAME'].describe()
# Out:
# count                                  109
# unique                                 106
# top       Clt - Active Cases with 70 or 71
# freq                                     2
# Name: SI_NAME, dtype: object

# %% [markdown]
# There are 109 listed reports. So, the **querybuilder_data** dataframe should have an indexes between 0-108. Now we can process with getting the rest of the information for each report.

# %% [markdown]
# ### SI_DESCRIPTION
#
# The description of each report is anywhere in **col1** where **SI_DESCRIPTION** is listed, the the description will be in **col2** on the same index.

# %%
querybuilder_data['SI_DESCRIPTION'] = qb[qb.iloc[:,0] == 'SI_DESCRIPTION'].iloc[:,1].reset_index(drop=True)
querybuilder_data.head()
# Out:
#                                           SI_NAME  \
# 0                            non-english x active
# 1                            CLT - Child Caseload
# 2      CRCF- Client Roster by CRCF with Addresses
# 3  Crosstab - Advoc & SvcAbbrev x month Dillon v2
# 4              Tx - 05 Transactions by Advoc 1 v2
#
#                        SI_DESCRIPTION SI_MAIL_SUBJECT SI_MAIL_ADDRESSES  \
# 0                monthly for Teresa C             NaN               NaN
# 1                   Monthly for Kathy             NaN               NaN
# 2  Monthly for Christian, Becky Black             NaN               NaN
# 3                  Monthly for Shawna             NaN               NaN
# 4            5th of Month for Roberta             NaN               NaN
#
#   SI_MAIL_CC SI_MAIL_BCC SI_MAIL_MESSAGE
# 0        NaN         NaN             NaN
# 1        NaN         NaN             NaN
# 2        NaN         NaN             NaN
# 3        NaN         NaN             NaN
# 4        NaN         NaN             NaN

# %% [markdown]
# ### SI_MAIL_SUBJECT
#
# The subject of the email containing the scheduled report is anywhere in **col4** where **SI_MAIL_SUBJECT** is listed. The subject will be on the same index in **col5**.

# %%
querybuilder_data['SI_MAIL_SUBJECT'] = qb[qb.iloc[:,3] == 'SI_MAIL_SUBJECT'].iloc[:,4].reset_index(drop=True)
querybuilder_data.head()
# Out:
#                                           SI_NAME  \
# 0                            non-english x active
# 1                            CLT - Child Caseload
# 2      CRCF- Client Roster by CRCF with Addresses
# 3  Crosstab - Advoc & SvcAbbrev x month Dillon v2
# 4              Tx - 05 Transactions by Advoc 1 v2
#
#                        SI_DESCRIPTION  \
# 0                monthly for Teresa C
# 1                   Monthly for Kathy
# 2  Monthly for Christian, Becky Black
# 3                  Monthly for Shawna
# 4            5th of Month for Roberta
#
#                               SI_MAIL_SUBJECT SI_MAIL_ADDRESSES SI_MAIL_CC  \
# 0                                   %SI_NAME%               NaN        NaN
# 1                    Monthly - Child Caseload               NaN        NaN
# 2                      Monthly - CRCF by CRCF               NaN        NaN
# 3  Monthly - xTab x Advoc & Svc abbr - Dillon               NaN        NaN
# 4          5th of Month - 05 Trans by Advoc 1               NaN        NaN
#
#   SI_MAIL_BCC SI_MAIL_MESSAGE
# 0         NaN             NaN
# 1         NaN             NaN
# 2         NaN             NaN
# 3         NaN             NaN
# 4         NaN             NaN

# %% [markdown]
# ### RECIPIENTS
# ___
# The recipients of the emails containing the scheduled reports is located in **col6** of the **qb** table. Since the recipient could be CC'd or BCC'd also there is a process to separate the emails. For every recipient in **col6** there is a number associated with the email at the same index in **col5**. This will help sort each email.
#
# The **SI_TOTAL** is an important variable. A recipient could be in the main **MAIL_ADDRESS**, **MAIL_CC**, or **MAIL_BCC** category. For each of the categories the **SI_TOTAL** lists how many emails are in each category.
#
# **EXAMPLE**
# SI_NAME: [REPORT_NAME]
# SI_DESCRIPTION: [REPORT_DESCRIPTION]
# SI_MAIL_SUBJECT: [REPORT SCHEDULE EMAIL SUBJECT]
# **SI_MAIL_ADDRESSES:** [REPORT SCHEDULE MAIN RECIPIENTS]
# * SI_TOTAL: 3 (Number of Recipients)
#         1. email
#         2. email
#         3. email
#
# **SI_MAIL_CC** [REPORT SCHEDULE CC'd RECIPIENTS]
#
# * SI_TOTAL: 2 (Number of Recipients)
#         1. email
#         2. email
#
# **SI_MAIL_BCC:** [REPORT SCHEDULE BCC'd RECIPIENTS]
# * SI_TOTAL: 1 (Number of Recipients)
#         1. email
#
# The **recipient type** is another variable that will be used listed in **col4**. In order to properly sort each email by the recipient type with the correct report, the recipient type needs to be listed by each recurring recipient. The code below will add the recipient type to each email like the example below.
#
# **Example**
#
# |Recipient Type   |SI TOTAL|Recipient |
# |-----------------|--------|----------|
# |SI_MAIL_ADDRESSES|1       |email1    |
# |SI_MAIL_ADDRESSES|2       |email2    |
# |SI_MAIL_ADDRESSES|3       |email3    |
# |SI_MAIL_CC       |1       |email1    |
# |SI_MAIL_CC       |2       |email2    |
# |SI_MAIL_BCC      |1       |email1    |

# %%
# Filter only for recipients types and keep the null values
recipients = qb[(qb.iloc[:,3] == 'SI_MAIL_ADDRESSES') |
                    (qb.iloc[:,3] == 'SI_MAIL_CC') |
                    (qb.iloc[:,3] == 'SI_MAIL_BCC')|
                    (pd.isna(qb.iloc[:,3]))]

# List the recipient type next to each email
temp_val = ''
temp_index = 0
for i, r in recipients.iterrows():
    
    if r[3] == 'SI_MAIL_ADDRESSES':
        temp_val = r[3]
        temp_index = i
    elif (recipients.loc[temp_index][3] == temp_val) and (r[3] != 'SI_MAIL_CC') and (r[3] != 'SI_MAIL_BCC'):
        r[3] = temp_val
        
    if r[3] == 'SI_MAIL_CC':
        temp_val = r[3]
        temp_index = i
    elif (recipients.loc[temp_index][3] == temp_val) and (r[3] != 'SI_MAIL_ADDRESSES') and (r[3] != 'SI_MAIL_BCC'):
        r[3] = temp_val
        
    if r[3] == 'SI_MAIL_BCC':
        temp_val = r[3]
        temp_index = i
    elif (recipients.loc[temp_index][3] == temp_val) and (r[3] != 'SI_MAIL_ADDRESSES') and (r[3] != 'SI_MAIL_CC'):
        r[3] = temp_val

recipients = recipients.iloc[:,[3,4,5]]

# Change columns names
recipients = recipients.rename(columns={recipients.columns[0]: 'recipient_type',
                                        recipients.columns[1]: 'si_total',
                                        recipients.columns[2]: 'recipients'}).reset_index(drop=True)
recipients.head(40)
# Out:
#        recipient_type  si_total          recipients
# 0                 NaN       NaN                 NaN
# 1                 NaN       NaN                 NaN
# 2                 NaN       NaN                 NaN
# 3                 NaN       NaN                 NaN
# 4                 NaN       NaN                 NaN
# 5                 NaN       NaN                 NaN
# 6                 NaN       NaN                 NaN
# 7                 NaN       NaN                 NaN
# 8                 NaN       NaN                 NaN
# 9                 NaN       NaN                 NaN
# 10                NaN       NaN                 NaN
# 11                NaN       NaN                 NaN
# 12                NaN       NaN                 NaN
# 13  SI_MAIL_ADDRESSES  SI_TOTAL                   1
# 14  SI_MAIL_ADDRESSES         1  Email1@example.org
# 15         SI_MAIL_CC  SI_TOTAL                   0
# 16        SI_MAIL_BCC  SI_TOTAL                   0
# 17        SI_MAIL_BCC         1        SI_MIME_TYPE
# 18        SI_MAIL_BCC       NaN       SI_EMBED_NAME
# 19        SI_MAIL_BCC       NaN                 NaN
# 20        SI_MAIL_BCC       NaN                 NaN
# 21        SI_MAIL_BCC       NaN                 NaN
# 22        SI_MAIL_BCC       NaN                 NaN
# 23        SI_MAIL_BCC       NaN                 NaN
# 24        SI_MAIL_BCC       NaN                 NaN
# 25        SI_MAIL_BCC       NaN                 NaN
# 26        SI_MAIL_BCC       NaN                 NaN
# 27  SI_MAIL_ADDRESSES  SI_TOTAL                   1
# 28  SI_MAIL_ADDRESSES         1  Email1@example.org
# 29         SI_MAIL_CC  SI_TOTAL                   0
# 30        SI_MAIL_BCC  SI_TOTAL                   0
# 31        SI_MAIL_BCC         1        SI_MIME_TYPE
# 32        SI_MAIL_BCC       NaN       SI_EMBED_NAME
# 33        SI_MAIL_BCC       NaN                 NaN
# 34        SI_MAIL_BCC       NaN                 NaN
# 35        SI_MAIL_BCC       NaN                 NaN
# 36        SI_MAIL_BCC       NaN                 NaN
# 37        SI_MAIL_BCC       NaN                 NaN
# 38        SI_MAIL_BCC       NaN                 NaN
# 39        SI_MAIL_BCC       NaN                 NaN

# %% [markdown]
# In the query builder, where there are multiple recipients, somtimes there are blanks where there should be an email. The code below will check if there are any missing emails.
#
# The code will check the **SI_TOTAL** and if there is a missing email it will replace the null (**Nan**) value with a blank
#
# **Example**
# * SI_TOTAL: 3
#     1. email
#     2. email
#     3. NaN

# %%
# Check for any possible missing emails
for i, r in recipients.iterrows():
    
    # Check SI_MAIL_ADDRESSES
    if (r['recipient_type'] == 'SI_MAIL_ADDRESSES') and (type(r['si_total']) == int) and (r['si_total'] >= 1):
        if pd.isna(r['recipients']):
            r['recipients'] = ''
            
    # Check SI_MAIL_CC
    if (r['recipient_type'] == 'SI_MAIL_CC') and (type(r['si_total']) == int) and (r['si_total'] >= 1):
        if pd.isna(r['recipients']):
            r['recipients'] = ''
            
    # Check SI_MAIL_BCC
    if (r['recipient_type'] == 'SI_MAIL_BCC') and (type(r['si_total']) == int) and (r['si_total'] >= 1):
        if pd.isna(r['recipients']):
            r['recipients'] = ''
                
# Filter the the column to contain only emails and possible missing emails
recipients = recipients[(recipients['recipients'].str.contains('@', flags=re.I, na=False, regex=True)) |
                        (recipients['recipients'] == '')].reset_index(drop=True)
recipients.iloc[49:62]
# Out:
#        recipient_type si_total          recipients
# 49  SI_MAIL_ADDRESSES        1  Email1@example.org
# 50  SI_MAIL_ADDRESSES        1  Email1@example.org
# 51  SI_MAIL_ADDRESSES        1  Email1@example.org
# 52  SI_MAIL_ADDRESSES        1  Email1@example.org
# 53  SI_MAIL_ADDRESSES        2  Email2@example.org
# 54  SI_MAIL_ADDRESSES        1  Email1@example.org
# 55  SI_MAIL_ADDRESSES        2  Email2@example.org
# 56         SI_MAIL_CC        1  Email1@example.org
# 57  SI_MAIL_ADDRESSES        1  Email1@example.org
# 58  SI_MAIL_ADDRESSES        2  Email2@example.org
# 59  SI_MAIL_ADDRESSES        3  Email3@example.org
# 60         SI_MAIL_CC        1  Email1@example.org
# 61         SI_MAIL_CC        2  Email2@example.org

# %% [markdown]
# Now that each recipient type is next to each recipient the emails can now be sorted to each report. The logic behind this is every email has to have recipients in the **SI_MAIL_ADDRESSES** category.
#
# **Example:**
#
# |Subject:|Email Subject|
# |---|---------|
# |To:|email1@example.com, email2@example.com, email3@example.com|
#
# This example would look like this in the **recipients table**
#
# |Recipient Type   |SI_TOTAL|Recipient |
# |-----------------|--------|----------|
# |SI_MAIL_ADDRESSES|1       |email1@example.com    |
# |SI_MAIL_ADDRESSES|2       |email2@example.com    |
# |SI_MAIL_ADDRESSES|3       |email3@example.com    |
#
# Sometimes there will be recipients that are CC'd or BCC'd
#
# **Example:**
#
# |Subject:|Email Subject|
# |---|---------|
# |To:|email1@example.com, email2@example.com, email3@example.com|
# |CC:|email1@example.com, email2@example.com|
# |BCC:|email1@example.com, email2@example.com|
#
# This example would look like this in the **recipients table**
#
#
# |Recipient Type   |SI_TOTAL|Recipient |
# |-----------------|--------|----------|
# |SI_MAIL_ADDRESSES|1       |email1@example.com    |
# |SI_MAIL_ADDRESSES|2       |email2@example.com    |
# |SI_MAIL_ADDRESSES|3       |email3@example.com    |
# |SI_MAIL_CC       |1       |email1@example.com    |
# |SI_MAIL_CC       |2       |email2@example.com    |
# |SI_MAIL_BCC       |1       |email1@example.com    |
# |SI_MAIL_BCC       |2       |email2@example.com    |
#
# If a recipient in the **SI_MAIL_CC** or/and **SI_MAIL_BCC** category follows the **SI_MAIL_ADDRESSES** category, it will be sorted into the same email. The code below will sort each email into its respective category.

# %%
# index counters for each recipient type
recipient_index = 0

for i, r in recipients.iterrows():
    
    if r['si_total'] == 1:
        if r['recipient_type'] == 'SI_MAIL_ADDRESSES':
            querybuilder_data.at[recipient_index, 'SI_MAIL_ADDRESSES'] = r['recipients']
            recipient_index += 1
        if r['recipient_type'] == 'SI_MAIL_CC':
            querybuilder_data.at[recipient_index - 1, 'SI_MAIL_CC'] = r['recipients']
        if r['recipient_type'] == 'SI_MAIL_BCC':
            querybuilder_data.at[recipient_index - 1, 'SI_MAIL_BCC'] = r['recipients']
    else:
        if r['recipient_type'] == 'SI_MAIL_ADDRESSES':
            querybuilder_data.at[recipient_index - 1, 'SI_MAIL_ADDRESSES'] = querybuilder_data.at[recipient_index - 1, 'SI_MAIL_ADDRESSES'] + ', ' + r['recipients']
        if r['recipient_type'] == 'SI_MAIL_CC':
            querybuilder_data.at[recipient_index - 1, 'SI_MAIL_CC'] = querybuilder_data.at[recipient_index - 1, 'SI_MAIL_CC'] + ', ' + r['recipients']
        if r['recipient_type'] == 'SI_MAIL_BCC':
            querybuilder_data.at[recipient_index - 1, 'SI_MAIL_BCC'] = querybuilder_data.at[recipient_index - 1, 'SI_MAIL_BCC'] + ', ' + r['recipients']
            
querybuilder_data.iloc[27:39]
# Out:
#                                               SI_NAME  \
# 27             620 Tx- Cancel NoShow Detail shows srv
# 28             603 Tx- Cancel NoShow Detail shows srv
# 29             560 Tx- Cancel NoShow Detail shows srv
# 30             539 Tx- Cancel NoShow Detail shows srv
# 31             376 Tx- Cancel NoShow Detail shows srv
# 32  EOC - Self-Pay Balances for Clients on DHEC De...
# 33                          noshow cfield new 7-19-19
# 34              Tx-Direct Services x Locat x Serv1 v2
# 35              640 Tx- Cancel NoShow Detail w srv v3
# 36             709 Tx- Cancel NoShow Detail shows srv
# 37                                     staff registry
# 38                   staff registry with non-billable
#
#                                SI_DESCRIPTION  \
# 27                    weekly for Evonne Young
# 28                   weekly for Cindy Griffin
# 29                    weekly for Ridgill Mims
# 30              weekly for Priscilla Morrison
# 31    automatically generated for Becky Black
# 32                                        NaN
# 33  new no show no onit daily for front staff
# 34                  Monthly for Christian, OM
# 35                       weekly for Anna Paul
# 36                 weekly for Miranda Roberts
# 37                       monthly for Teresa C
# 38                       monthly for Teresa C
#
#                            SI_MAIL_SUBJECT  \
# 27                               %SI_NAME%
# 28                               %SI_NAME%
# 29                               %SI_NAME%
# 30                               %SI_NAME%
# 31                               %SI_NAME%
# 32             monthly - DHEC death report
# 33                               %SI_NAME%
# 34  Monthly - Tx Direct Serv x Loc x Serv1
# 35                               %SI_NAME%
# 36                               %SI_NAME%
# 37                               %SI_NAME%
# 38                               %SI_NAME%
#
#                                     SI_MAIL_ADDRESSES  \
# 27                                 Email1@example.org
# 28                                 Email1@example.org
# 29                                 Email1@example.org
# 30                                 Email1@example.org
# 31                                 Email1@example.org
# 32             Email1@example.org, Email2@example.org
# 33             Email1@example.org, Email2@example.org
# 34  Email1@example.org, Email2@example.org, Email3...
# 35                                 Email1@example.org
# 36                                 Email1@example.org
# 37                                 Email1@example.org
# 38                                 Email1@example.org
#
#                                 SI_MAIL_CC         SI_MAIL_BCC SI_MAIL_MESSAGE
# 27                                     NaN                 NaN             NaN
# 28                                     NaN                 NaN             NaN
# 29                                     NaN                 NaN             NaN
# 30                                     NaN                 NaN             NaN
# 31                                     NaN                 NaN             NaN
# 32                                     NaN                 NaN             NaN
# 33                      Email1@example.org                 NaN             NaN
# 34  Email1@example.org, Email2@example.org                 NaN             NaN
# 35                                     NaN                 NaN             NaN
# 36                                     NaN                 NaN             NaN
# 37                                     NaN  Email1@example.org             NaN
# 38                                     NaN  Email1@example.org             NaN

# %%
print('Number of rows: ', querybuilder_data.shape[0])
# Out:
# Number of rows:  109

# %% [markdown]
# ##### There are still 109 rows corresponding to the 109 different reports that were counted at the beginning of the project. This means that the emails have been sorted correctly.

# %% [markdown]
# ### SI_MAIL_MESSAGE
#
# Now that the recipients are sorted by the correct reports the body of each email now can be sorted. The body of the email is anywhere in **col4** where **SI_MAIL_MESSAGE** is listed. The body will be at the same index in **col5**.

# %%
querybuilder_data['SI_MAIL_MESSAGE'] = qb[qb.iloc[:,3] == 'SI_MAIL_MESSAGE'].iloc[:,4].reset_index(drop=True)
querybuilder_data.head(10)
# Out:
#                                           SI_NAME  \
# 0                            non-english x active
# 1                            CLT - Child Caseload
# 2      CRCF- Client Roster by CRCF with Addresses
# 3  Crosstab - Advoc & SvcAbbrev x month Dillon v2
# 4              Tx - 05 Transactions by Advoc 1 v2
# 5                   Tx- H056 H057 H058 H059 FY 18
# 6              MCO in H003, 004, 005 w names FY19
# 7                Clt - FollowUp Consent Labels v2
# 8              Clt - Followup Consent Y's only v3
# 9                 Clt - Active Clients w SC Prime
#
#                        SI_DESCRIPTION  \
# 0                monthly for Teresa C
# 1                   Monthly for Kathy
# 2  Monthly for Christian, Becky Black
# 3                  Monthly for Shawna
# 4            5th of Month for Roberta
# 5      weekly on Fridays for Teresa C
# 6      weekly on Fridays for Teresa C
# 7                  Monthly for Kaylah
# 8                  Monthly for Kaylah
# 9                 Monthly for Roberta
#
#                               SI_MAIL_SUBJECT  \
# 0                                   %SI_NAME%
# 1                    Monthly - Child Caseload
# 2                      Monthly - CRCF by CRCF
# 3  Monthly - xTab x Advoc & Svc abbr - Dillon
# 4          5th of Month - 05 Trans by Advoc 1
# 5                                   %SI_NAME%
# 6                                   %SI_NAME%
# 7      Monthly - Clt Follow Up Consent Labels
# 8                  Monthly - Followup Consent
# 9                monthly - Act Cli w SC Prime
#
#                                    SI_MAIL_ADDRESSES SI_MAIL_CC SI_MAIL_BCC  \
# 0                                 Email1@example.org        NaN         NaN
# 1                                 Email1@example.org        NaN         NaN
# 2             Email1@example.org, Email2@example.org        NaN         NaN
# 3                                 Email1@example.org        NaN         NaN
# 4                                 Email1@example.org        NaN         NaN
# 5                                 Email1@example.org        NaN         NaN
# 6                                 Email1@example.org        NaN         NaN
# 7                                 Email1@example.org        NaN         NaN
# 8                                 Email1@example.org        NaN         NaN
# 9  Email1@example.org, Email2@example.org, Email3...        NaN         NaN
#
#                                      SI_MAIL_MESSAGE
# 0                  added 1/4/19 monthly for Teresa C
# 1                            Automatically generated
# 2                            Automatically generated
# 3                            Automatically generated
# 4  automatically generated updated 7/11/18 to rep...
# 5                   fixed migration schedule 3/18/19
# 6                   fixed migration schedule 3/18/19
# 7                            Automatically generated
# 8                            Automatically generated
# 9  automatically generated updated 7/11/18 to rep...

# %% [markdown]
# # Final Results

# %%
querybuilder_data
# Out:
#                                                SI_NAME  \
# 0                                 non-english x active
# 1                                 CLT - Child Caseload
# 2           CRCF- Client Roster by CRCF with Addresses
# 3       Crosstab - Advoc & SvcAbbrev x month Dillon v2
# 4                   Tx - 05 Transactions by Advoc 1 v2
# 5                        Tx- H056 H057 H058 H059 FY 18
# 6                   MCO in H003, 004, 005 w names FY19
# 7                     Clt - FollowUp Consent Labels v2
# 8                   Clt - Followup Consent Y's only v3
# 9                      Clt - Active Clients w SC Prime
# 10                    Clt - Active Cases with 70 or 71
# 11                    Clt - Active Cases with 70 or 71
# 12             Clt - Discharged Clients by Location v2
# 13           CLT - No PMA master list- w Mcaid numbers
# 14                  CRCF - Client Alpha Roster by CSMG
# 15                      Clt- Mcare#s with ABN dates v2
# 16               Tx- Cancel NoShow Detail shows srv v2
# 17               579 Tx- Cancel NoShow Detail w srv v3
# 18        Crosstab - Advoc & SvcAbbrev x month Ches v2
# 19              696 Tx- Cancel NoShow Detail shows srv
# 20              687 Tx- Cancel NoShow Detail shows srv
# 21              679 Tx- Cancel NoShow Detail shows srv
# 22              675 Tx- Cancel NoShow Detail shows srv
# 23              665 Tx- Cancel NoShow Detail shows srv
# 24              650 Tx- Cancel NoShow Detail shows srv
# 25              651 Tx- Cancel NoShow Detail shows srv
# 26              623 Tx- Cancel NoShow Detail shows srv
# 27              620 Tx- Cancel NoShow Detail shows srv
# 28              603 Tx- Cancel NoShow Detail shows srv
# 29              560 Tx- Cancel NoShow Detail shows srv
# 30              539 Tx- Cancel NoShow Detail shows srv
# 31              376 Tx- Cancel NoShow Detail shows srv
# 32   EOC - Self-Pay Balances for Clients on DHEC De...
# 33                           noshow cfield new 7-19-19
# 34               Tx-Direct Services x Locat x Serv1 v2
# 35               640 Tx- Cancel NoShow Detail w srv v3
# 36              709 Tx- Cancel NoShow Detail shows srv
# 37                                      staff registry
# 38                    staff registry with non-billable
# 39    Contacts vs Undup Contacts x Srv x age x prev mo
# 40                             694 Notes Signed Status
# 41                             701 Notes Signed Status
# 42                    Tx- Cancel NoShow for doctors v3
# 43              710 Tx- Cancel NoShow Detail shows srv
# 44                    Clt - Financial Eval by Locat Q1
# 45                    Clt - Financial Eval by Locat Q2
# 46                    Clt - Financial Eval by Locat Q3
# 47                    Clt - Financial Eval by Locat Q4
# 48                      CLT - MCAID active by location
# 49                   CLT - NO MCAID active by location
# 50                            Clt- MCare Admissions v2
# 51   Tx- Clt Missing Srvcs H003 H004 H005 not admit...
# 52         Clt - Active Caseload with Addresses by Loc
# 53                    Lookup-Insurance Code Listing v2
# 54              Clt - Last Service 45 days v2 - Bville
# 55             Clt - Last Service 45 days v2 - C'field
# 56              Clt - Last Service 45 days v2 - Dillon
# 57                             586 Notes Signed Status
# 58                                   Self Pay Bills v5
# 59    CLT - Child Caseload for Voter Registration Form
# 60                      Clt - missing clinical info v2
# 61   Engagement 1.2 - Caseload x CSMG - wi last SRV...
# 62                        Adm - Bed Days x 10th of Mth
# 63         Adm - Hosp Admissions for the last month v2
# 64           Clt - Active Caseload - Last Srv1 no H052
# 65               Clt - Active Caseload - Last Srv1 PMA
# 66                  Clt - Active Caseload - Summary v2
# 67   Clt - Active Cases to Review for Closing - No ...
# 68   Clt - Caseload Report x Case Manager x CMHC - ...
# 69   Clt - Caseload Report x Case Manager x CMHC - ...
# 70             Clt No PMA over 60 days from adm dat v3
# 71             Clt No PMA over 60 days from adm dat v3
# 72                                  Clt-New Admissions
# 73                                      Clt-weekly LOC
# 74        Crosstab - Advoc & SvcAbbrev x month Benn v2
# 75          Crosstab - Advoc & SvcAbbrev x monthrpt v2
# 76                                   discharge x death
# 77         DLA - DLA-20 Change Scores - Active Clients
# 78         DLA - DLA-20 Summary by Locat over 5 Bville
# 79         DLA - DLA-20 Summary by Locat over 5 Cfield
# 80         DLA - DLA-20 Summary by Locat over 5 Dillon
# 81                         Doctor Cancel NoShow Bville
# 82                         Doctor Cancel NoShow Cfield
# 83                         Doctor Cancel NoShow Dillon
# 84                  inpat-Current Inpatients - Monthly
# 85               Referral to Appointment C20 Report v2
# 86                Sched - Schedules at a Glance - Week
# 87                  Tx - 07 Transactions by Advoc 1 v2
# 88          Tx - Billable x Loc x Off x Adv x Payor v3
# 89                Tx - Bus Days from Adm to 1st Tx Svc
# 90   Tx- Cancel NoShow by tx-locat summary only for...
# 91   Tx- H052 Transactions for TriCounty with date ...
# 92      Tx-Direct Services x Office x Locat x Adult v2
# 93   Tx-Direct Services x Office x Locat x Children v2
# 94                                     unassigned csmg
# 95                                          Clt No PMA
# 96      CLT- Cases for Review - Exclude PMA by CSMG v2
# 97   Sched - Cancel - No-Show Appointments x Locat ...
# 98   Sched - Cancel - No-Show Appointments x Csmg w...
# 99      ICT Tx - Direct Services x Clinician x prev mo
# 100  Tx - Direct Services with SPD Hrs - Summary - ...
# 101           ICT note signed status CANNED prev month
# 102  ICT - Direct Services with SPD Hrs - Summary -...
# 103       Clt - Active Clients w Insurance by Locat v2
# 104            Clt - Active Clients with Payor Sources
# 105                          noshow bville new 7-19-19
# 106                 Clt - Active Clients w MCAID HMO's
# 107                          noshow dillon new 7-19-19
# 108                           EMR- Unsigned Tickets v2
#
#                                         SI_DESCRIPTION  \
# 0                                 monthly for Teresa C
# 1                                    Monthly for Kathy
# 2                   Monthly for Christian, Becky Black
# 3                                   Monthly for Shawna
# 4                             5th of Month for Roberta
# 5                       weekly on Fridays for Teresa C
# 6                       weekly on Fridays for Teresa C
# 7                                   Monthly for Kaylah
# 8                                   Monthly for Kaylah
# 9                                  Monthly for Roberta
# 10                                      2 Weeks for OM
# 11                                      2 Weeks for OM
# 12                           Monthly for Christian, OM
# 13                                      Monthly for OM
# 14              Monthly for Christian, OM, Becky Black
# 15                                      Monthly for OM
# 16                      Monthly for Christian, Michael
# 17                              weekly for Eunece Bell
# 18                                  Monthly for Vivian
# 19                        weekly for Samantha McKenzie
# 20                            weekly for Kenya Frazier
# 21                           weekly for Marsha Jackson
# 22                            weekly for Quaneaka Reed
# 23                             weekly Tabitha Hennagan
# 24                         weekly for Michael Stolarik
# 25                             weekly for Eli Rinehart
# 26                           weekly for Sumner Garland
# 27                             weekly for Evonne Young
# 28                            weekly for Cindy Griffin
# 29                             weekly for Ridgill Mims
# 30                       weekly for Priscilla Morrison
# 31             automatically generated for Becky Black
# 32                                                 NaN
# 33           new no show no onit daily for front staff
# 34                           Monthly for Christian, OM
# 35                                weekly for Anna Paul
# 36                          weekly for Miranda Roberts
# 37                                monthly for Teresa C
# 38                                monthly for Teresa C
# 39                                 monthly for Crystal
# 40                             6th of month for Bertha
# 41                            6th of month for Madyson
# 42                   monthly for Teresa C, Dr. Sachdev
# 43                            weekly for Beverly Mason
# 44                                    Quarterly for DE
# 45                                    Quarterly for DE
# 46                                    Quarterly for DE
# 47                                    Quarterly for DE
# 48                                      Monthly for DE
# 49                                      Monthly for DE
# 50                Monthly for OM, Teresa, Becky, Cathy
# 51                                  Monthly for OM, DE
# 52                                         Monthly for
# 53                               Quarterly for Roberta
# 54                        Bi-Monthly for Teresa C, OMs
# 55                        Bi-Monthly for Teresa C, OMs
# 56                        Bi-Monthly for Teresa C, OMs
# 57                              6th of month for Aimee
# 58               every other 10th of month for Felicia
# 59                   Monthly for Teresa C, Michael, DE
# 60                Monthly for Michael, OM, MRC, Teresa
# 61                  monthly for Christian, Michael, OM
# 62              5th of Month for Teresa Curry, Michael
# 63              5th of month for Teresa Curry, Michael
# 64   Detail report of active clients with cid, name...
# 65   Detail report of active clients with cid, name...
# 66                                                 NaN
# 67                           Monthly for Christian, OM
# 68                             Bi-Monthly for Teresa C
# 69                             Bi-Monthly for Teresa C
# 70   Detail List of all clients who have received n...
# 71   Detail List of all clients who have received n...
# 72                      monthly for Christian, Michael
# 73                             weekly for Teresa L, OM
# 74                          Monthly for Michael, Kathy
# 75              Monthly for Christian, Michael, Teresa
# 76                                 monthly for Michael
# 77        Monthly for Christian, Michael, OM, Teresa C
# 78                         Monthly for Michael and OMs
# 79                         monthly for Michael and OMs
# 80                         monthly for Michael and OMs
# 81                     monthly for Michael, Teresa M L
# 82   Detail of each Clinician's Cancel/No Show Appt...
# 83   Detail of each Clinician's Cancel/No Show Appt...
# 84                                 Monthly for Michael
# 85                               Monthly for Christian
# 86   Appointments and Available Times from Schedule...
# 87              Monthly for Roberta & OM & Secretaries
# 88          Monthly for Teresa Curry, Michael, Crystal
# 89        monthly for Christian, Michael, Teresa C, OM
# 90                      Monthly for Christian, Michael
# 91                                 Monthly for Michael
# 92                      Monthly for Christian, Michael
# 93                      Monthly for Christian, Michael
# 94                         Monthly for Michael, Teresa
# 95                               monthly for Christian
# 96                                      Monthly for OM
# 97                  Monthly for Christian, Michael, OM
# 98                  Monthly for Christian, Michael, OM
# 99                              Monthly for Aimee, TML
# 100  Weekly for Teresa C, Dr. Sachdev, Teresa L, Cr...
# 101                                monthly for Aimee M
# 102                                monthly for Aimee M
# 103                 Quarterly for Roberta, Secretaries
# 104                                     Monthly for DE
# 105          new no show no onit daily for front staff
# 106                                     Monthly for DE
# 107          new no show no onit daily for front staff
# 108                                     Monthly for OM
#
#                                        SI_MAIL_SUBJECT  \
# 0                                            %SI_NAME%
# 1                             Monthly - Child Caseload
# 2                               Monthly - CRCF by CRCF
# 3           Monthly - xTab x Advoc & Svc abbr - Dillon
# 4                   5th of Month - 05 Trans by Advoc 1
# 5                                            %SI_NAME%
# 6                                            %SI_NAME%
# 7               Monthly - Clt Follow Up Consent Labels
# 8                           Monthly - Followup Consent
# 9                         monthly - Act Cli w SC Prime
# 10         Twice Monthly - Clt Active Cases w 70 or 71
# 11         Twice Monthly - Clt Active Cases w 70 or 71
# 12                     Monthly - Discharged Clts x Loc
# 13                    Monthly - No PMA w Mcaid numbers
# 14                       Monthly - CRCF Roster by CSMG
# 15                      Monthly - Mcare#s w/ ABN dates
# 16              Monthly - Cancel No Show Detail w/ srv
# 17                                           %SI_NAME%
# 18              Monthly - xTab Advoc & Svc abbr - Ches
# 19                                           %SI_NAME%
# 20                                           %SI_NAME%
# 21                                           %SI_NAME%
# 22                                           %SI_NAME%
# 23                                           %SI_NAME%
# 24                                           %SI_NAME%
# 25                                           %SI_NAME%
# 26                                           %SI_NAME%
# 27                                           %SI_NAME%
# 28                                           %SI_NAME%
# 29                                           %SI_NAME%
# 30                                           %SI_NAME%
# 31                                           %SI_NAME%
# 32                         monthly - DHEC death report
# 33                                           %SI_NAME%
# 34              Monthly - Tx Direct Serv x Loc x Serv1
# 35                                           %SI_NAME%
# 36                                           %SI_NAME%
# 37                                           %SI_NAME%
# 38                                           %SI_NAME%
# 39                                           %SI_NAME%
# 40                                           %SI_NAME%
# 41                                           %SI_NAME%
# 42                                           %SI_NAME%
# 43                                           %SI_NAME%
# 44                 Quarterly - Financial Eval by Locat
# 45                 Quarterly - Financial Eval by Locat
# 46                 Quarterly - Financial Eval by Locat
# 47                 Quarterly - Financial Eval by Locat
# 48               6th of month - Clt Mcaid Active x Loc
# 49                 Monthly - Clt No Mcaid Active x Loc
# 50                          Monthly - MCare Admissions
# 51   Monthly - Clts Missing Srvs H003,4,5 not admit...
# 52                Monthly - Active Caseload w/ Address
# 53                        Quarterly - Ins Code Listing
# 54                                           %SI_NAME%
# 55                                           %SI_NAME%
# 56                                           %SI_NAME%
# 57                                           %SI_NAME%
# 58                         self pay monthly 10th of mo
# 59   monthly - age 18 + or - 30 days for voter regi...
# 60                      Clt - missing clinical info v2
# 61                                           %SI_NAME%
# 62                                           %SI_NAME%
# 63                                           %SI_NAME%
# 64           monthly - Last PMA > 180 and missing H052
# 65            monthly - Active Caseload Last Srv > 180
# 66           Monthly - CLT - Active Caseload - Summary
# 67   Monthly - Act Cases to Review for Close - No Serv
# 68                                           %SI_NAME%
# 69                                           %SI_NAME%
# 70      Bi-Monthly - no PMA over 60 days from adm date
# 71      Bi-Monthly - no PMA over 60 days from adm date
# 72                      monthly - Clt - New Admissions
# 73                                           %SI_NAME%
# 74            Monthly - xTab x Advoc & Srv abbr - Benn
# 75                     Montlhy - xTab Advoc & Svc abbr
# 76                                           %SI_NAME%
# 77         Monthly - DLA change scores summ act cli v2
# 78                      monthly - DLA-20 over 5 Bville
# 79                DLA-20 Summ by locat over 5 - cfield
# 80                DLA-20 Summ by locat over 5 - Dillon
# 81                     bville doctor no-show prev week
# 82                     cfield doctor no-show prev week
# 83                  dillon weekly doc noshow prev week
# 84                        monthly - current inpatients
# 85                      Monthly - Referral to Appt C20
# 86                                           %SI_NAME%
# 87                       Monthly - 07 Trans by Advoc 1
# 88                                           %SI_NAME%
# 89                                 monthly - %SI_NAME%
# 90   Monthly - Tx Cancel No Show local summary for ...
# 91               monthly - TX H052 Trans w distinct ct
# 92        Monthly - Tx Direct Serv x Off x Loc x Adult
# 93     Monthly - Tx Direct Serv x Off x Loc x Children
# 94                           monthly - unassigned csgm
# 95                     monthly - clt - no PMA no dates
# 96     Monthly - CLT Cases for Review Excl PMA by CSMG
# 97            monthly - cancel no show summary x advoc
# 98          monthly - cancel no show x advoc x summary
# 99                                           %SI_NAME%
# 100                                          %SI_NAME%
# 101                                          %SI_NAME%
# 102                                          %SI_NAME%
# 103               Quarterly - Act Clients w Ins by Loc
# 104           Monthly - Active Clts with payor sources
# 105                                          %SI_NAME%
# 106                      monthly - Act Cli w MCAID HMO
# 107                                          %SI_NAME%
# 108                       Daily - EMR Unsigned Tickets
#
#                                      SI_MAIL_ADDRESSES  \
# 0                                   Email1@example.org
# 1                                   Email1@example.org
# 2               Email1@example.org, Email2@example.org
# 3                                   Email1@example.org
# 4                                   Email1@example.org
# 5                                   Email1@example.org
# 6                                   Email1@example.org
# 7                                   Email1@example.org
# 8                                   Email1@example.org
# 9    Email1@example.org, Email2@example.org, Email3...
# 10   Email1@example.org, Email2@example.org, Email3...
# 11   Email1@example.org, Email2@example.org, Email3...
# 12   Email1@example.org, Email2@example.org, Email3...
# 13   Email1@example.org, Email2@example.org, Email3...
# 14   Email1@example.org, Email2@example.org, Email3...
# 15   Email1@example.org, Email2@example.org, Email3...
# 16   Email1@example.org, Email2@example.org, Email3...
# 17                                  Email1@example.org
# 18                                  Email1@example.org
# 19                                  Email1@example.org
# 20                                  Email1@example.org
# 21                                  Email1@example.org
# 22                                  Email1@example.org
# 23                                  Email1@example.org
# 24                                  Email1@example.org
# 25                                  Email1@example.org
# 26                                  Email1@example.org
# 27                                  Email1@example.org
# 28                                  Email1@example.org
# 29                                  Email1@example.org
# 30                                  Email1@example.org
# 31                                  Email1@example.org
# 32              Email1@example.org, Email2@example.org
# 33              Email1@example.org, Email2@example.org
# 34   Email1@example.org, Email2@example.org, Email3...
# 35                                  Email1@example.org
# 36                                  Email1@example.org
# 37                                  Email1@example.org
# 38                                  Email1@example.org
# 39                                  Email1@example.org
# 40                                  Email1@example.org
# 41                                  Email1@example.org
# 42              Email1@example.org, Email2@example.org
# 43                                  Email1@example.org
# 44   Email1@example.org, Email2@example.org, Email3...
# 45   Email1@example.org, Email2@example.org, Email3...
# 46   Email1@example.org, Email2@example.org, Email3...
# 47   Email1@example.org, Email2@example.org, Email3...
# 48   Email1@example.org, Email2@example.org, Email3...
# 49   Email1@example.org, Email2@example.org, Email3...
# 50   Email1@example.org, Email2@example.org, Email3...
# 51   Email1@example.org, Email2@example.org, Email3...
# 52   Email1@example.org, Email2@example.org, Email3...
# 53   Email1@example.org, Email2@example.org, Email3...
# 54                                  Email1@example.org
# 55                                  Email1@example.org
# 56                                  Email1@example.org
# 57                                  Email1@example.org
# 58                                  Email1@example.org
# 59   Email1@example.org, Email2@example.org, Email3...
# 60   Email1@example.org, Email2@example.org, Email3...
# 61   Email1@example.org, Email2@example.org, Email3...
# 62                                  Email1@example.org
# 63                                  Email1@example.org
# 64                                  Email1@example.org
# 65                                  Email1@example.org
# 66   Email1@example.org, Email2@example.org, Email3...
# 67   Email1@example.org, Email2@example.org, Email3...
# 68              Email1@example.org, Email2@example.org
# 69              Email1@example.org, Email2@example.org
# 70   Email1@example.org, Email2@example.org, Email3...
# 71   Email1@example.org, Email2@example.org, Email3...
# 72                                  Email1@example.org
# 73   Email1@example.org, Email2@example.org, Email3...
# 74                                  Email1@example.org
# 75                                  Email1@example.org
# 76                                  Email1@example.org
# 77   Email1@example.org, Email2@example.org, Email3...
# 78              Email1@example.org, Email2@example.org
# 79              Email1@example.org, Email2@example.org
# 80              Email1@example.org, Email2@example.org
# 81                                  Email1@example.org
# 82                                  Email1@example.org
# 83                                  Email1@example.org
# 84   Email1@example.org, Email2@example.org, Email3...
# 85                                  Email1@example.org
# 86   Email1@example.org, Email2@example.org, Email3...
# 87   Email1@example.org, Email2@example.org, Email3...
# 88              Email1@example.org, Email2@example.org
# 89   Email1@example.org, Email2@example.org, Email3...
# 90                                Email1@example.org,
# 91                                  Email1@example.org
# 92                                  Email1@example.org
# 93                                  Email1@example.org
# 94                                  Email1@example.org
# 95                                  Email1@example.org
# 96   Email1@example.org, Email2@example.org, Email3...
# 97   Email1@example.org, Email2@example.org, Email3...
# 98                                  Email1@example.org
# 99                                  Email1@example.org
# 100  Email1@example.org, Email2@example.org, Email3...
# 101                                 Email1@example.org
# 102                                 Email1@example.org
# 103  Email1@example.org, Email2@example.org, Email3...
# 104  Email1@example.org, Email2@example.org, Email3...
# 105                                 Email1@example.org
# 106  Email1@example.org, Email2@example.org, Email3...
# 107             Email1@example.org, Email2@example.org
# 108  Email1@example.org, Email2@example.org, Email3...
#
#                                             SI_MAIL_CC         SI_MAIL_BCC  \
# 0                                                  NaN                 NaN
# 1                                                  NaN                 NaN
# 2                                                  NaN                 NaN
# 3                                                  NaN                 NaN
# 4                                                  NaN                 NaN
# 5                                                  NaN                 NaN
# 6                                                  NaN                 NaN
# 7                                                  NaN                 NaN
# 8                                                  NaN                 NaN
# 9                                                  NaN                 NaN
# 10                                                 NaN                 NaN
# 11                                                 NaN                 NaN
# 12                                                 NaN                 NaN
# 13                                                 NaN                 NaN
# 14                                                 NaN                 NaN
# 15                                                 NaN                 NaN
# 16                                                 NaN                 NaN
# 17                                                 NaN                 NaN
# 18                                                 NaN                 NaN
# 19                                                 NaN                 NaN
# 20                                                 NaN                 NaN
# 21                                                 NaN                 NaN
# 22                                                 NaN                 NaN
# 23                                                 NaN                 NaN
# 24                                                 NaN                 NaN
# 25                                                 NaN                 NaN
# 26                                                 NaN                 NaN
# 27                                                 NaN                 NaN
# 28                                                 NaN                 NaN
# 29                                                 NaN                 NaN
# 30                                                 NaN                 NaN
# 31                                                 NaN                 NaN
# 32                                                 NaN                 NaN
# 33                                  Email1@example.org                 NaN
# 34              Email1@example.org, Email2@example.org                 NaN
# 35                                                 NaN                 NaN
# 36                                                 NaN                 NaN
# 37                                                 NaN  Email1@example.org
# 38                                                 NaN  Email1@example.org
# 39                                                 NaN                 NaN
# 40                                                 NaN                 NaN
# 41                                                 NaN                 NaN
# 42                                                 NaN                 NaN
# 43                                                 NaN                 NaN
# 44                                                 NaN  Email1@example.org
# 45                                                 NaN                 NaN
# 46                                                 NaN                 NaN
# 47                                                 NaN                 NaN
# 48                                                 NaN                 NaN
# 49                                                 NaN                 NaN
# 50   Email1@example.org, Email2@example.org, Email3...                 NaN
# 51   Email1@example.org, Email2@example.org, Email3...                 NaN
# 52   Email1@example.org, Email2@example.org, Email3...                 NaN
# 53   Email1@example.org, Email2@example.org, Email3...                 NaN
# 54                                  Email1@example.org  Email1@example.org
# 55                                  Email1@example.org  Email1@example.org
# 56                                  Email1@example.org  Email1@example.org
# 57                                                 NaN                 NaN
# 58                                  Email1@example.org  Email1@example.org
# 59   Email1@example.org, Email2@example.org, Email3...                 NaN
# 60                                                 NaN  Email1@example.org
# 61                                                 NaN                 NaN
# 62                                                 NaN  Email1@example.org
# 63                                                 NaN  Email1@example.org
# 64                                                 NaN                 NaN
# 65                                                 NaN  Email1@example.org
# 66                                                 NaN                 NaN
# 67                                                 NaN                 NaN
# 68                                                 NaN  Email1@example.org
# 69                                                 NaN  Email1@example.org
# 70                                  Email1@example.org                 NaN
# 71                                  Email1@example.org                 NaN
# 72                                                 NaN  Email1@example.org
# 73              Email1@example.org, Email2@example.org                 NaN
# 74                                                 NaN                 NaN
# 75                                                 NaN                 NaN
# 76                                                 NaN                 NaN
# 77                                  Email1@example.org                 NaN
# 78                                                 NaN  Email1@example.org
# 79                                                 NaN  Email1@example.org
# 80                                                 NaN  Email1@example.org
# 81                                  Email1@example.org                 NaN
# 82                                  Email1@example.org                 NaN
# 83                                  Email1@example.org                 NaN
# 84              Email1@example.org, Email2@example.org                 NaN
# 85                                                 NaN                 NaN
# 86              Email1@example.org, Email2@example.org                 NaN
# 87                                  Email1@example.org                 NaN
# 88                                                 NaN                 NaN
# 89                                  Email1@example.org  Email1@example.org
# 90                                                 NaN                 NaN
# 91                                                 NaN                 NaN
# 92                                                 NaN                 NaN
# 93                                                 NaN                 NaN
# 94                                                 NaN                 NaN
# 95                                                 NaN                 NaN
# 96                                                 NaN                 NaN
# 97                                  Email1@example.org                 NaN
# 98                                                 NaN  Email1@example.org
# 99                                  Email1@example.org  Email1@example.org
# 100                                                NaN  Email1@example.org
# 101                                                NaN  Email1@example.org
# 102                                                NaN                 NaN
# 103                                 Email1@example.org                 NaN
# 104                                                NaN                 NaN
# 105                                 Email1@example.org                 NaN
# 106                                                NaN  Email1@example.org
# 107                                 Email1@example.org                 NaN
# 108             Email1@example.org, Email2@example.org  Email1@example.org
#
#                                        SI_MAIL_MESSAGE
# 0                    added 1/4/19 monthly for Teresa C
# 1                              Automatically generated
# 2                              Automatically generated
# 3                              Automatically generated
# 4    automatically generated updated 7/11/18 to rep...
# 5                     fixed migration schedule 3/18/19
# 6                     fixed migration schedule 3/18/19
# 7                              Automatically generated
# 8                              Automatically generated
# 9    automatically generated updated 7/11/18 to rep...
# 10                             automatically generated
# 11                             automatically generated
# 12                             automatically generated
# 13                             automatically generated
# 14                             automatically generated
# 15                             automatically generated
# 16                             automatically generated
# 17                             automatically generated
# 18                             automatically generated
# 19                             automatically generated
# 20                             automatically generated
# 21                             automatically generated
# 22                             automatically generated
# 23                             automatically generated
# 24                             automatically generated
# 25                             automatically generated
# 26                             automatically generated
# 27                             automatically generated
# 28                             automatically generated
# 29                             automatically generated
# 30                             automatically generated
# 31                             automatically generated
# 32                             automatically generated
# 33                             automatically generated
# 34                             Automatically generated
# 35                                                 NaN
# 36                             automatically generated
# 37                             automatically generated
# 38                             automatically generated
# 39                             automatically generated
# 40        automatically generated on 6th of each month
# 41        automatically generated on 6th of each month
# 42                             automatically generated
# 43       automatically generated weekly no-show report
# 44                             automatically generated
# 45                             automatically generated
# 46                             automatically generated
# 47                             automatically generated
# 48                             automatically generated
# 49                             automatically generated
# 50                             automatically generated
# 51                             automatically generated
# 52                             automatically generated
# 53                             Automatically generated
# 54                      automatically generated weekly
# 55                      automatically generated weekly
# 56                      automatically generated weekly
# 57        automatically generated on 6th of each month
# 58                             automatically generated
# 59                             automatically generated
# 60   now including clients with missing physician a...
# 61                             automatically generated
# 62                                                 NaN
# 63                                                 NaN
# 64                             automatically generated
# 65                             automatically generated
# 66                             automatically generated
# 67                             automatically generated
# 68                  automatically generated bi-monthly
# 69                  automatically generated bi-monthly
# 70                             automatically generated
# 71                             automatically generated
# 72                             automatically generated
# 73                             automatically generated
# 74                             Automatically generated
# 75                             Automatically generated
# 76           automatically generated 1st of each month
# 77                             automatically generated
# 78                             automatically generated
# 79                             automatically generated
# 80                             automatically generated
# 81                             automatically generated
# 82                             automatically generated
# 83                             automatically generated
# 84                     Automatically generated monthly
# 85                             Automatically generated
# 86                          new weekly schedule report
# 87                             automatically generated
# 88                   automatically generated - monthly
# 89                             automatically generated
# 90                             Automatically generated
# 91                             automatically generated
# 92                             Automatically generated
# 93                             Automatically generated
# 94                             automatically generated
# 95                             automatically generated
# 96                             automatically generated
# 97            automatically generated; sorted by locat
# 98        automatically generated; not sorted by locat
# 99   automatically generated 8th day of each month ...
# 100  automatically generated weekly updated for 803...
# 101  automatically generated 8th day of each month ...
# 102  automatically generated 8th day of each month ...
# 103                            automatically generated
# 104                            automatically generated
# 105                            automatically generated
# 106                            automatically generated
# 107                            automatically generated
# 108                            automatically generated

# %% [markdown]
# ### Store DataFrame into Excel

# %%
querybuilder_data.to_excel('QueryBuilder_cleaned.xlsx', index=False)
